# %%
import pandas as pd
df = pd.read_csv("train.csv")

# %%
df.head()
# Out:
#    Store  Dept       Date  Weekly_Sales  IsHoliday
# 0      1     1 2010-02-05      24924.50      False
# 1      1     1 2010-02-12      46039.49       True
# 2      1     1 2010-02-19      41595.55      False
# 3      1     1 2010-02-26      19403.54      False
# 4      1     1 2010-03-05      21827.90      False

# %%
 df["Date"] = pd.to_datetime(df["Date"])

# %%
week = []
year = []
for i in range(len(df)):
    week.append(df["Date"][i].week)
    year.append(df["Date"][i].year)
df["week"] = week
df["year"] = year

# %%
df[df["year"] == 2011]
# Out:
#         Store  Dept       Date  Weekly_Sales  IsHoliday  week  year
# 48          1     1 2011-01-07      15984.24      False     1  2011
# 49          1     1 2011-01-14      17359.70      False     2  2011
# 50          1     1 2011-01-21      17341.47      False     3  2011
# 51          1     1 2011-01-28      18461.18      False     4  2011
# 52          1     1 2011-02-04      21665.76      False     5  2011
# ...       ...   ...        ...           ...        ...   ...   ...
# 421522     45    98 2011-12-02        538.51      False    48  2011
# 421523     45    98 2011-12-09        572.72      False    49  2011
# 421524     45    98 2011-12-16        853.46      False    50  2011
# 421525     45    98 2011-12-23       1084.78      False    51  2011
# 421526     45    98 2011-12-30        553.21       True    52  2011
#
# [153453 rows x 7 columns]

# %%
df["IsHoliday"] = df["IsHoliday"].astype("float64")

# %%
df.dtypes
# Out:
# Store                    int64
# Dept                     int64
# Date            datetime64[ns]
# Weekly_Sales           float64
# IsHoliday              float64
# week                     int64
# year                     int64
# dtype: object

# %%
df.to_csv("train_modified.csv")

# %%
temp = df[df["Store"] == 1]

# %%
temp = temp[temp["year"] == 2010]

# %%
temp.sort_values("Date",inplace=True)

# %%
temp.head()
# Out:
#       Store  Dept       Date  Weekly_Sales  IsHoliday  week  year
# 0         1     1 2010-02-05      24924.50        0.0     5  2010
# 5690      1    44 2010-02-05       4674.75        0.0     5  2010
# 5833      1    45 2010-02-05         37.44        0.0     5  2010
# 5904      1    46 2010-02-05      20837.77        0.0     5  2010
# 715       1     6 2010-02-05       5749.03        0.0     5  2010

# %%
temp["Dept"].unique()
# Out:
# array([ 1, 44, 45, 46,  6, 47, 48, 49, 51, 52, 54, 55,  5, 56, 42, 58, 60,
#        67, 71,  4, 72, 74, 79, 80, 81,  3, 82, 83, 85, 59, 41, 40,  7, 13,
#        11, 14, 16, 17, 18, 19, 20, 10, 21, 22, 23, 24, 25, 26,  9, 27, 28,
#        29, 30, 31, 32,  8, 33, 34, 35, 36, 37, 38, 87, 90, 12,  2, 93, 95,
#        97, 98, 91, 92, 94, 78, 99, 96], dtype=int64)

# %%
temp1 = temp[temp["Dept"] == 46]

# %%
temp1.head()
# Out:
#       Store  Dept       Date  Weekly_Sales  IsHoliday  week  year
# 5904      1    46 2010-02-05      20837.77        0.0     5  2010
# 5905      1    46 2010-02-12      18826.47        1.0     6  2010
# 5906      1    46 2010-02-19      22414.94        0.0     7  2010
# 5907      1    46 2010-02-26      18099.75        0.0     8  2010
# 5908      1    46 2010-03-05      20565.45        0.0     9  2010

# %%
import matplotlib.pyplot as plt

plt.plot(temp1["week"],temp1["Weekly_Sales"],color = 'r')

# %%
len(temp)
# Out:
# 3443

# %%
df1 = pd.read_csv("features.csv")

# %%
df1.sort_values("Date",inplace=True)

# %%
df1.head(20)
# Out:
#       Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0         1  2010-02-05        42.31       2.572        NaN        NaN
# 2730     16  2010-02-05        19.79       2.580        NaN        NaN
# 5460     31  2010-02-05        39.05       2.572        NaN        NaN
# 3640     21  2010-02-05        39.05       2.572        NaN        NaN
# 4550     26  2010-02-05         9.55       2.788        NaN        NaN
# 7280     41  2010-02-05        30.27       2.580        NaN        NaN
# 2548     15  2010-02-05        19.83       2.954        NaN        NaN
# 5642     32  2010-02-05        34.43       2.580        NaN        NaN
# 910       6  2010-02-05        40.43       2.572        NaN        NaN
# 3458     20  2010-02-05        25.92       2.784        NaN        NaN
# 1274      8  2010-02-05        34.14       2.572        NaN        NaN
# 2366     14  2010-02-05        27.31       2.784        NaN        NaN
# ...

# %%
len(df1)
# Out:
# 8190

# %%
len(df["Date"].unique())
# Out:
# 143

# %%
df1.reset_index(inplace = True)
df1.head()
# Out:
#    index  Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0      0      1  2010-02-05        42.31       2.572        NaN        NaN
# 1   2730     16  2010-02-05        19.79       2.580        NaN        NaN
# 2   5460     31  2010-02-05        39.05       2.572        NaN        NaN
# 3   3640     21  2010-02-05        39.05       2.572        NaN        NaN
# 4   4550     26  2010-02-05         9.55       2.788        NaN        NaN
#
#    MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# 0        NaN        NaN        NaN  211.096358         8.106      False
# 1        NaN        NaN        NaN  189.381697         7.039      False
# 2        NaN        NaN        NaN  210.752605         8.324      False
# 3        NaN        NaN        NaN  210.752605         8.324      False
# 4        NaN        NaN        NaN  131.527903         8.488      False

# %%
df1.drop(["index"],axis=1,inplace=True)

# %%
df1.head()
# Out:
#    Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0      1  2010-02-05        42.31       2.572        NaN        NaN
# 1     16  2010-02-05        19.79       2.580        NaN        NaN
# 2     31  2010-02-05        39.05       2.572        NaN        NaN
# 3     21  2010-02-05        39.05       2.572        NaN        NaN
# 4     26  2010-02-05         9.55       2.788        NaN        NaN
#
#    MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# 0        NaN        NaN        NaN  211.096358         8.106      False
# 1        NaN        NaN        NaN  189.381697         7.039      False
# 2        NaN        NaN        NaN  210.752605         8.324      False
# 3        NaN        NaN        NaN  210.752605         8.324      False
# 4        NaN        NaN        NaN  131.527903         8.488      False

# %%
df3 = df

# %%
df3.head()
# Out:
#    Store  Dept       Date  Weekly_Sales  IsHoliday  week  year
# 0      1     1 2010-02-05      24924.50        0.0     5  2010
# 1      1     1 2010-02-12      46039.49        1.0     6  2010
# 2      1     1 2010-02-19      41595.55        0.0     7  2010
# 3      1     1 2010-02-26      19403.54        0.0     8  2010
# 4      1     1 2010-03-05      21827.90        0.0     9  2010

# %%
df3 = df.sort_values(["Date"])

# %%
df3.head()
# Out:
#         Store  Dept       Date  Weekly_Sales  IsHoliday  week  year
# 0           1     1 2010-02-05      24924.50        0.0     5  2010
# 277665     29     5 2010-02-05      15552.08        0.0     5  2010
# 277808     29     6 2010-02-05       3200.22        0.0     5  2010
# 277951     29     7 2010-02-05      10820.05        0.0     5  2010
# 278094     29     8 2010-02-05      20055.64        0.0     5  2010

# %%
df3 = df3.sort_values(["Store"])

# %%
df3.head()
# Out:
#       Store  Dept       Date  Weekly_Sales  IsHoliday  week  year
# 0         1     1 2010-02-05      24924.50        0.0     5  2010
# 8285      1    81 2011-03-25      29498.03        0.0    12  2011
# 6892      1    56 2012-01-27       1438.75        0.0     4  2012
# 7440      1    67 2011-08-12       5265.80        0.0    32  2011
# 9715      1    95 2011-03-25     122280.13        0.0    12  2011

# %%
df1.head()
# Out:
#    Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0      1  2010-02-05        42.31       2.572        NaN        NaN
# 1     16  2010-02-05        19.79       2.580        NaN        NaN
# 2     31  2010-02-05        39.05       2.572        NaN        NaN
# 3     21  2010-02-05        39.05       2.572        NaN        NaN
# 4     26  2010-02-05         9.55       2.788        NaN        NaN
#
#    MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# 0        NaN        NaN        NaN  211.096358         8.106      False
# 1        NaN        NaN        NaN  189.381697         7.039      False
# 2        NaN        NaN        NaN  210.752605         8.324      False
# 3        NaN        NaN        NaN  210.752605         8.324      False
# 4        NaN        NaN        NaN  131.527903         8.488      False

# %%
df3.head()
# Out:
#         Store  Dept       Date  Weekly_Sales  IsHoliday  week  year
# 0           1     1 2010-02-05      24924.50        0.0     5  2010
# 277665     29     5 2010-02-05      15552.08        0.0     5  2010
# 277808     29     6 2010-02-05       3200.22        0.0     5  2010
# 277951     29     7 2010-02-05      10820.05        0.0     5  2010
# 278094     29     8 2010-02-05      20055.64        0.0     5  2010

# %%
df3.reset_index(inplace = True)
df3.head()
# Out:
#     index  Store  Dept       Date  Weekly_Sales  IsHoliday  week  year
# 0       0      1     1 2010-02-05      24924.50        0.0     5  2010
# 1  277665     29     5 2010-02-05      15552.08        0.0     5  2010
# 2  277808     29     6 2010-02-05       3200.22        0.0     5  2010
# 3  277951     29     7 2010-02-05      10820.05        0.0     5  2010
# 4  278094     29     8 2010-02-05      20055.64        0.0     5  2010

# %%
df3.drop(["index"],axis=1,inplace = True)

# %%
df3.head()
# Out:
#    Store  Dept       Date  Weekly_Sales  IsHoliday  week  year  Temperature
# 0      1     1 2010-02-05      24924.50        0.0     5  2010            0
# 1     29     5 2010-02-05      15552.08        0.0     5  2010            0
# 2     29     6 2010-02-05       3200.22        0.0     5  2010            0
# 3     29     7 2010-02-05      10820.05        0.0     5  2010            0
# 4     29     8 2010-02-05      20055.64        0.0     5  2010            0

# %%
df3.drop(["Temperature"],axis=1,inplace=True)

# %%
df3.head()
# Out:
#    Store  Dept       Date  Weekly_Sales  IsHoliday  week  year
# 0      1     1 2010-02-05      24924.50        0.0     5  2010
# 1     29     5 2010-02-05      15552.08        0.0     5  2010
# 2     29     6 2010-02-05       3200.22        0.0     5  2010
# 3     29     7 2010-02-05      10820.05        0.0     5  2010
# 4     29     8 2010-02-05      20055.64        0.0     5  2010

# %%
df3["CPI"] = [0]*len(df3)

# %%
df3.head()
# Out:
#    Store  Dept       Date  Weekly_Sales  IsHoliday  week  year  CPI
# 0      1     1 2010-02-05      24924.50        0.0     5  2010    0
# 1     29     5 2010-02-05      15552.08        0.0     5  2010    0
# 2     29     6 2010-02-05       3200.22        0.0     5  2010    0
# 3     29     7 2010-02-05      10820.05        0.0     5  2010    0
# 4     29     8 2010-02-05      20055.64        0.0     5  2010    0

# %%
df3["Temperature"] = [0]*len(df3)

# %%
df3["Fuel_Price"] = [0]*len(df3)

# %%
df3["Unemployment"] = [0]*len(df3)

# %%
df3.head()
# Out:
#    Store  Dept       Date  Weekly_Sales  IsHoliday  week  year  CPI  \
# 0      1     1 2010-02-05      24924.50        0.0     5  2010    0
# 1     29     5 2010-02-05      15552.08        0.0     5  2010    0
# 2     29     6 2010-02-05       3200.22        0.0     5  2010    0
# 3     29     7 2010-02-05      10820.05        0.0     5  2010    0
# 4     29     8 2010-02-05      20055.64        0.0     5  2010    0
#
#    Temperature  Fuel_Price  Unemployment
# 0            0           0             0
# 1            0           0             0
# 2            0           0             0
# 3            0           0             0
# 4            0           0             0

# %%
df3["Date"] = df3["Date"].astype("str")
df1["Date"] = df1["Date"].astype("str")

# %%
for i in range(len(df3)):
    M = df1[df1["Date"] == df3["Date"][i]]
    K = M[M["Store"] == df3["Store"][i]]
    df3["CPI"][i] = list(K["CPI"])[0]
    df3["Temperature"][i] = list(K["Temperature"])[0]
    df3["Fuel_Price"][i] = list(K["Fuel_Price"])[0]
    df3["Unemployment"][i] = list(K["Unemployment"])[0]
# Out:
# <ipython-input-133-d11631c5bc8c>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3["CPI"][i] = list(K["CPI"])[0]
# <ipython-input-133-d11631c5bc8c>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3["Temperature"][i] = list(K["Temperature"])[0]
# <ipython-input-133-d11631c5bc8c>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3["Fuel_Price"][i] = list(K["Fuel_Price"])[0]
# ...

# %%
df3.to_csv("train_modified1.csv")

# %%
df3 = pd.read_csv("train_modified1.csv")

# %%
df3.head()
# Out:
#    Unnamed: 0  Store  Dept        Date  Weekly_Sales  IsHoliday  week  year  \
# 0           0      1     1  2010-02-05      24924.50        0.0     5  2010
# 1           1     29     5  2010-02-05      15552.08        0.0     5  2010
# 2           2     29     6  2010-02-05       3200.22        0.0     5  2010
# 3           3     29     7  2010-02-05      10820.05        0.0     5  2010
# 4           4     29     8  2010-02-05      20055.64        0.0     5  2010
#
#    CPI  Temperature  Fuel_Price  Unemployment
# 0  211           42           2             8
# 1  131           24           2            10
# 2  131           24           2            10
# 3  131           24           2            10
# 4  131           24           2            10

# %%
df3["Date"] = pd.to_datetime(df3["Date"])

# %%
month = []
day = []
for i in range(len(df3)):
    month.append(df3["Date"][i].month)
    day.append(df3["Date"][i].day)

# %%
df3["Date"][i].day
# Out:
# 26

# %%
df3["month"] = month
df3["day"] = day

# %%
df3.head()
# Out:
#    Unnamed: 0  Store  Dept       Date  Weekly_Sales  IsHoliday  week  year  \
# 0           0      1     1 2010-02-05      24924.50        0.0     5  2010
# 1           1     29     5 2010-02-05      15552.08        0.0     5  2010
# 2           2     29     6 2010-02-05       3200.22        0.0     5  2010
# 3           3     29     7 2010-02-05      10820.05        0.0     5  2010
# 4           4     29     8 2010-02-05      20055.64        0.0     5  2010
#
#    CPI  Temperature  Fuel_Price  Unemployment  month  day
# 0  211           42           2             8      2    5
# 1  131           24           2            10      2    5
# 2  131           24           2            10      2    5
# 3  131           24           2            10      2    5
# 4  131           24           2            10      2    5

# %%
df3.drop(["Unnamed: 0"],axis=1,inplace = True)

# %%
df3.corr()
# Out:
#                  Store      Dept  Weekly_Sales  IsHoliday      week      year  \
# Store         1.000000  0.024004     -0.085195  -0.000548  0.001031  0.002997
# Dept          0.024004  1.000000      0.148032   0.000916  0.000882  0.003738
# Weekly_Sales -0.085195  0.148032      1.000000   0.012774  0.027673 -0.010111
# IsHoliday    -0.000548  0.000916      0.012774   1.000000  0.128184 -0.056746
# week          0.001031  0.000882      0.027673   0.128184  1.000000 -0.181797
# year          0.002997  0.003738     -0.010111  -0.056746 -0.181797  1.000000
# CPI          -0.211004 -0.007456     -0.020942  -0.001847  0.006236  0.074776
# Temperature  -0.050018  0.004432     -0.002339  -0.156176  0.235817  0.065743
# Fuel_Price    0.047192  0.004589      0.001127  -0.024875 -0.015534  0.722214
# Unemployment  0.207191  0.007884     -0.025566   0.013617 -0.012629 -0.249319
# month         0.001011  0.000904      0.028409   0.123376  0.995999 -0.194288
# ...

# %%
df3.to_csv("train_modified1.csv")

# %%
temp = df3[df3["Store"] == 1]

# %%
temp.head()
# Out:
#      Store  Dept       Date  Weekly_Sales  IsHoliday  week  year  CPI  \
# 0        1     1 2010-02-05      24924.50        0.0     5  2010  211
# 698      1    49 2010-02-05      11501.46        0.0     5  2010  211
# 706      1    48 2010-02-05        814.00        0.0     5  2010  211
# 709      1    47 2010-02-05         70.00        0.0     5  2010  211
# 712      1    51 2010-02-05          1.16        0.0     5  2010  211
#
#      Temperature  Fuel_Price  Unemployment  month  day
# 0             42           2             8      2    5
# 698           42           2             8      2    5
# 706           42           2             8      2    5
# 709           42           2             8      2    5
# 712           42           2             8      2    5

# %%
temp1 = temp[temp["Dept"] == 1]

# %%
temp1
# Out:
#         Store  Dept       Date  Weekly_Sales  IsHoliday  week  year  CPI  \
# 0           1     1 2010-02-05      24924.50        0.0     5  2010  211
# 5747        1     1 2010-02-12      46039.49        1.0     6  2010  211
# 6829        1     1 2010-02-19      41595.55        0.0     7  2010  211
# 11698       1     1 2010-02-26      19403.54        0.0     8  2010  211
# 12681       1     1 2010-03-05      21827.90        0.0     9  2010  211
# ...       ...   ...        ...           ...        ...   ...   ...  ...
# 409016      1     1 2012-09-28      18947.81        0.0    39  2012  222
# 411919      1     1 2012-10-05      21904.47        0.0    40  2012  223
# 415480      1     1 2012-10-12      22764.01        0.0    41  2012  223
# 415817      1     1 2012-10-19      24185.27        0.0    42  2012  223
# 418672      1     1 2012-10-26      27390.81        0.0    43  2012  223
#
#         Temperature  Fuel_Price  Unemployment  month  day
# ...

# %%
temp2 = temp1[temp1["year"] == 2010]

# %%
import matplotlib.pyplot as plt
plt.plot(temp2["week"],temp2["Weekly_Sales"])
